# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../src")

import pandas as pd

from content_based import (
    create_content_features,
    build_tfidf_matrix,
    compute_similarity_matrix,
    recommend_movies
)

movies = pd.read_csv("../data/processed/movies_clean.csv")

movies = create_content_features(movies)

tfidf_matrix, vectorizer = build_tfidf_matrix(movies)

similarity_matrix = compute_similarity_matrix(tfidf_matrix)

recommend_movies(
    movie_title="American Pie",
    movies=movies,
    similarity_matrix=similarity_matrix,
    top_n=5
)
# Out:
#       movieId                                              title  genres  \
# 3459     4718                              American Pie 2 (2001)  Comedy
# 4461     6586           American Wedding (American Pie 3) (2003)  Comedy
# 7857    93831           American Reunion (American Pie 4) (2012)  Comedy
# 7217    73106  American Pie Presents: The Book of Love (Ameri...  Comedy
# 6042    39715  American Pie Presents: Band Camp (American Pie...  Comedy
#
#         year  similarity_score
# 3459  2001.0             0.964
# 4461  2003.0             0.818
# 7857  2012.0             0.786
# 7217  2009.0             0.688
# 6042  2005.0             0.627
